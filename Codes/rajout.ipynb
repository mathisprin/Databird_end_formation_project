# %%
import pandas as pd
import numpy as np

# %%
df_hebergement = pd.read_csv('Liste_hebergement_tourisme&handicapCLEAN.csv')
df_hebergement
# Out:
#       Unnamed: 0                             Nom de l'établissement  \
# 0              0              EDF- Centrale hydraulique de la Rance
# 1              1                       Le Gîte d'Enora - Quemeneven
# 2              2                                   Gite de Kerlouan
# 3              3                         CELTAVENTURES SARL CAPALOU
# 4              4                    Chambres d'Hôtes de la Cotterie
# ...          ...                                                ...
# 3755        3755                                   Gîte le Pic Vert
# 3756        3756  Office de Tourisme des Hauts du Lyonnais - Mai...
# 3757        3757                                    Meublé 17G84016
# 3758        3758                             Gîte des Retrouvailles
# 3759        3759                                  Meublé Le Pesquit
#
#                     Commune     CP                 Région  \
# 0             LA RICHARDAIS  35780               Bretagne
# ...

# %%
df_hebergement['Sensoriel'].replace({'1': True, '0': False}, inplace=True)
df_hebergement['Cognitif'].replace({'1': True, '0': False}, inplace=True)
df_hebergement['Physique'].replace({'1': True, '0': False}, inplace=True)
df_hebergement
# Out:
#       Unnamed: 0                             Nom de l'établissement  \
# 0              0              EDF- Centrale hydraulique de la Rance
# 1              1                       Le Gîte d'Enora - Quemeneven
# 2              2                                   Gite de Kerlouan
# 3              3                         CELTAVENTURES SARL CAPALOU
# 4              4                    Chambres d'Hôtes de la Cotterie
# ...          ...                                                ...
# 3755        3755                                   Gîte le Pic Vert
# 3756        3756  Office de Tourisme des Hauts du Lyonnais - Mai...
# 3757        3757                                    Meublé 17G84016
# 3758        3758                             Gîte des Retrouvailles
# 3759        3759                                  Meublé Le Pesquit
#
#                     Commune     CP                 Région  \
# 0             LA RICHARDAIS  35780               Bretagne
# ...

# %%
df_hebergement.to_csv('Liste_hebergement_tourisme&handicapCLEAN.csv')

# %%
df_etablissement = pd.read_csv('liste_etablissements_tourisme&handicapCLEAN.csv')
df_etablissement
# Out:
#       Unnamed: 0                             Nom de l'établissement  \
# 0              0                       Le Gîte d'Enora - Quemeneven
# 1              1                                   Gite de Kerlouan
# 2              2                         CELTAVENTURES SARL CAPALOU
# 3              3                    Chambres d'Hôtes de la Cotterie
# 4              4                Gîte rural de la Coutellerie 150058
# ...          ...                                                ...
# 3754        3754                                   Gîte le Pic Vert
# 3755        3755  Office de Tourisme des Hauts du Lyonnais - Mai...
# 3756        3756                                    Meublé 17G84016
# 3757        3757                             Gîte des Retrouvailles
# 3758        3758                                  Meublé Le Pesquit
#
#                     Commune     CP                 Région  \
# 0                QUEMENEVEN  29180               Bretagne
# ...

# %%
df_etablissement['Sensoriel']
# Out:
# 0       1
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 3754    1
# 3755    1
# 3756    1
# 3757    1
# 3758    1
# Name: Sensoriel, Length: 3759, dtype: object

# %%
df_etablissement['Sensoriel'].replace({'1': True, '0': False}, inplace=True)

# %%
df_etablissement['Cognitif'].replace({'1': True, '0': False}, inplace=True)
df_etablissement['Physique'].replace({'1': True, '0': False}, inplace=True)
df_etablissement
# Out:
#       Unnamed: 0                             Nom de l'établissement  \
# 0              0                       Le Gîte d'Enora - Quemeneven
# 1              1                                   Gite de Kerlouan
# 2              2                         CELTAVENTURES SARL CAPALOU
# 3              3                    Chambres d'Hôtes de la Cotterie
# 4              4                Gîte rural de la Coutellerie 150058
# ...          ...                                                ...
# 3754        3754                                   Gîte le Pic Vert
# 3755        3755  Office de Tourisme des Hauts du Lyonnais - Mai...
# 3756        3756                                    Meublé 17G84016
# 3757        3757                             Gîte des Retrouvailles
# 3758        3758                                  Meublé Le Pesquit
#
#                     Commune     CP                 Région  \
# 0                QUEMENEVEN  29180               Bretagne
# ...

# %%
df_etablissement.to_csv('liste_etablissements_tourisme&handicapCLEAN.csv')

# %%
df_soins = pd.read_csv('base-soins.csv')
df_soins
# Out:
#       Unnamed: 0    _id                                 title  \
# 0              0  91378                  SPASAD Bresse Dombes
# 1              1  91377                  SPASAD de la Côtière
# 2              2    110                                 SSIAD
# 3              3     16          SSIAD ADAPA Miribel-Montluel
# 4              4     70          SSIAD ASDOMI Bourg-en-Bresse
# ...          ...    ...                                   ...
# 5812        5812   3874          SSIAD Départementale ADMR 2A
# 5813        5813   3885             SSIAD Union des mutuelles
# 5814        5814   3923                           SSIAD AMAPA
# 5815        5815   3922              SSIAD Aiutu e Solidarita
# 5816        5816   3926  SSIAD Fédération ADMR de Haute-Corse
#
#                              courriel  SSIAD  SPASAD  SAAD  \
# 0          schatillon@fede01.admr.org      0       1     0
# 1                                 NaN      0       1     0
# ...

# %%
dic_numeros_departements = {
    "01": "Ain",
    "02": "Aisne",
    "03": "Allier",
    "04": "Alpes-de-Haute-Provence",
    "05": "Hautes-Alpes",
    "06": "Alpes-Maritimes",
    "07": "Ardèche",
    "08": "Ardennes",
    "09": "Ariège",
    "10": "Aube",
    "11": "Aude",
    "12": "Aveyron",
    "13": "Bouches-du-Rhône",
    "14": "Calvados",
    "15": "Cantal",
    "16": "Charente",
    "17": "Charente-Maritime",
    "18": "Cher",
    "19": "Corrèze",
    "20": "Haute-Corse",
    "21": "Côte-d'Or",
    "22": "Côtes d'Armor",
    "23": "Creuse",
    "24": "Dordogne",
    "25": "Doubs",
    "26": "Drôme",
    "27": "Eure",
    "28": "Eure-et-Loire",
    "29": "Finistère",
    "30": "Gard",
    "31": "Haute-Garonne",
    "32": "Gers",
    "33": "Gironde",
    "34": "Hérault",
    "35": "Ille-et-Vilaine",
    "36": "Indre",
    "37": "Indre-et-Loire",
    "38": "Isère",
    "39": "Jura",
    "40": "Landes",
    "41": "Loir-et-Cher",
    "42": "Loire",
    "43": "Haute-Loire",
    "44": "Loire-Atlantique",
    "45": "Loiret",
    "46": "Lot",
    "47": "Lot-et-Garonne",
    "48": "Lozère",
    "49": "Maine-et-Loire",
    "50": "Manche",
    "51": "Marne",
    "52": "Haute-Marne",
    "53": "Mayenne",
    "54": "Meurthe-et-Moselle",
    "55": "Meuse",
    "56": "Morbihan",
    "57": "Moselle",
    "58": "Nièvre",
    "59": "Nord",
    "60": "Oise",
    "61": "Orne",
    "62": "Pas-de-Calais",
    "63": "Puy-de-Dôme",
    "64": "Pyrénées-Atlantiques",
    "65": "Hautes-Pyrénées",
    "66": "Pyrénées-Orientales",
    "67": "Bas-Rhin",
    "68": "Haut-Rhin",
    "69": "Rhône",
    "70": "Haute-Saône",
    "71": "Saône-et-Loire",
    "72": "Sarthe",
    "73": "Savoie",
    "74": "Haute-Savoie",
    "75": "Paris",
    "76": "Seine-Maritime",
    "77": "Seine-et-Marne",
    "78": "Yvelines",
    "79": "Deux-Sèvres",
    "80": "Somme",
    "81": "Tarn",
    "82": "Tarn-et-Garonne",
    "83": "Var",
    "84": "Vaucluse",
    "85": "Vendée",
    "86": "Vienne",
    "87": "Haute-Vienne",
    "88": "Vosges",
    "89": "Yonne",
    "90": "Territoire de Belfort",
    "91": "Essonne",
    "92": "Hauts-de-Seine",
    "93": "Seine-Saint-Denis",
    "94": "Val-de-Marne",
    "95": "Val-d'Oise",
    "971": "Guadeloupe",
    "972": "Martinique",
    "973": "Guyane",
    "974": "La Réunion",
    "976": "Mayotte"
    }

# %%
# Création de la colonne numero_departement
df_soins['nom_departement'] = pd.NA

# Boucle pour ajouter le numero_departement associé au département
for numeros_departement, nom_departement in dic_numeros_departements.items():
    
    # si le nom du departement est le même on ajoute le numéros associé 
    df_soins.loc[df_soins['departement'] == int(numeros_departement), 'nom_departement'] = nom_departement
df_soins
# Out:
#       Unnamed: 0    _id                                 title  \
# 0              0  91378                  SPASAD Bresse Dombes
# 1              1  91377                  SPASAD de la Côtière
# 2              2    110                                 SSIAD
# 3              3     16          SSIAD ADAPA Miribel-Montluel
# 4              4     70          SSIAD ASDOMI Bourg-en-Bresse
# ...          ...    ...                                   ...
# 5812        5812   3874          SSIAD Départementale ADMR 2A
# 5813        5813   3885             SSIAD Union des mutuelles
# 5814        5814   3923                           SSIAD AMAPA
# 5815        5815   3922              SSIAD Aiutu e Solidarita
# 5816        5816   3926  SSIAD Fédération ADMR de Haute-Corse
#
#                              courriel  SSIAD  SPASAD  SAAD  \
# 0          schatillon@fede01.admr.org      0       1     0
# 1                                 NaN      0       1     0
# ...

# %%
df_soins['departement'].unique()
# Out:
# array([14, 10, 15, 17, 12, 11, 13, 18, 16, 20, 25, 24, 23, 22, 21, 28, 26,
#        27, 30, 31, 32, 33, 41, 42, 40, 47, 43, 48, 45, 51, 55, 57, 54, 53,
#        50, 52, 61, 67, 64, 66, 60, 63, 62, 68, 65, 74, 72, 70, 71, 78, 73,
#        77, 86, 85, 82, 83, 84, 80, 91, 94, 90, 93, 92, 96, 98, 95, 97, 19,
#        29, 34, 35, 36, 37, 38, 39, 44, 46, 49, 56, 58, 59, 69, 75, 76, 79,
#        81, 87, 88, 89], dtype=int64)

# %%
df_soins.drop('Unnamed: 0', axis=1, inplace=True)
df_soins
# Out:
#         _id                                 title  \
# 0     91378                  SPASAD Bresse Dombes
# 1     91377                  SPASAD de la Côtière
# 2       110                                 SSIAD
# 3        16          SSIAD ADAPA Miribel-Montluel
# 4        70          SSIAD ASDOMI Bourg-en-Bresse
# ...     ...                                   ...
# 5812   3874          SSIAD Départementale ADMR 2A
# 5813   3885             SSIAD Union des mutuelles
# 5814   3923                           SSIAD AMAPA
# 5815   3922              SSIAD Aiutu e Solidarita
# 5816   3926  SSIAD Fédération ADMR de Haute-Corse
#
#                              courriel  SSIAD  SPASAD  SAAD  \
# 0          schatillon@fede01.admr.org      0       1     0
# 1                                 NaN      0       1     0
# 2             ssiadgiedair@wanadoo.fr      1       0     0
# 3                   adapa@adapa01.com      1       0     0
# 4                     ssiad@asdomi.fr      1       0     0
# ...

# %%
df_soins.to_csv('base-soins.csv')
