# %%
import json
import requests
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Via API

# %%
base_url = "https://acceslibre.beta.gouv.fr/api/"
endpoint = "erps"
url = base_url + endpoint

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'count': 128368,
#  'page_size': 20,
#  'next': 'https://acceslibre.beta.gouv.fr/api/erps/?page=2',
#  'previous': None,
#  'results': [{'url': 'https://acceslibre.beta.gouv.fr/api/erps/cafe-citron/',
#    'web_url': 'https://acceslibre.beta.gouv.fr/app/75-paris/a/restaurant/erp/cafe-citron/',
#    'uuid': 'aae6687e-46c7-4b92-a44b-c30109edea57',
#    'activite': {'nom': 'Restaurant', 'slug': 'restaurant'},
#    'nom': '01 - Café Vira',
#    'slug': 'cafe-citron',
#    'adresse': '60 Avenue des Champs-Élysées, 75008 Paris',
#    'commune': 'Paris',
#    'code_insee': None,
#    'code_postal': '75008',
#    'geom': {'type': 'Point',
#     'coordinates': [2.306074798107148, 48.87063241820194]},
#    'siret': None,
#    'telephone': '01 83 65 61 08',
#    'site_internet': 'https://www.vira.fr',
#    'contact_email': 'contact@vira.fr',
#    'contact_url': 'https://www.vira.fr/contact',
#    'user_type': 'system',
# ...

# %%
data = response.json()
data.keys()
# Out:
# dict_keys(['count', 'page_size', 'next', 'previous', 'results'])

# %%
print(f"Type de data['results']: {type(data['results'])}")
data['results']
# Out:
# Type de data['results']: <class 'list'>
# [{'url': 'https://acceslibre.beta.gouv.fr/api/erps/cafe-citron/',
#   'web_url': 'https://acceslibre.beta.gouv.fr/app/75-paris/a/restaurant/erp/cafe-citron/',
#   'uuid': 'aae6687e-46c7-4b92-a44b-c30109edea57',
#   'activite': {'nom': 'Restaurant', 'slug': 'restaurant'},
#   'nom': '01 - Café Vira',
#   'slug': 'cafe-citron',
#   'adresse': '60 Avenue des Champs-Élysées, 75008 Paris',
#   'commune': 'Paris',
#   'code_insee': None,
#   'code_postal': '75008',
#   'geom': {'type': 'Point',
#    'coordinates': [2.306074798107148, 48.87063241820194]},
#   'siret': None,
#   'telephone': '01 83 65 61 08',
#   'site_internet': 'https://www.vira.fr',
#   'contact_email': 'contact@vira.fr',
#   'contact_url': 'https://www.vira.fr/contact',
#   'user_type': 'system',
#   'accessibilite': {'url': 'https://acceslibre.beta.gouv.fr/api/accessibilite/132735/',
#    'erp': 'https://acceslibre.beta.gouv.fr/api/erps/cafe-citron/',
# ...

# %% [markdown]
# # Via CSV

# %%
df = pd.read_csv("acceslibre-with-web-url.csv")
df
# Out:
# C:\Users\prinm\AppData\Local\Temp\ipykernel_20668\1780367359.py:1: DtypeWarning: Columns (7,56,71) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("acceslibre-with-web-url.csv")
#                                           id                         name  \
# 0       aae6687e-46c7-4b92-a44b-c30109edea57             01 - Café Citron
# 1       76538c2d-2be8-486b-ab23-b0e434c8c414                 01 Fleuriste
# 2       ebf08662-e4fd-46b1-a706-1bd7f0e1706f               030 L'Opticien
# 3       c7d781c0-12cf-4d66-aeef-571d8d4efd4f                    0'mok@bar
# 4       893019fe-cf9e-405e-9423-91955766cb45                         0RPI
# ...                                      ...                          ...
# 128360  8e465598-fd19-44f6-908c-91ce5b6c991b                         Zumo
# 128361  378be594-d387-49b1-857a-bfd76731ec08                         Zumo
# 128362  557e264b-8099-4c2e-8b5f-86c0f3b31f57                 Zumus Hookah
# ...

# %%
df['transport_station_presence'].unique()
# Out:
# array([True, nan, False], dtype=object)
